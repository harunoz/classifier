# %%
import os
from collections import Counter
import math
import pandas as pd 

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
#from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('textFiles.csv')

# %%
data
# Out:
#     Unnamed: 0 FileName FileType  FileSize  FileEntropy  FileSizeAppended  \
# 0            0  File101     TEXT      1679     4.608124             10553
# 1            1  File102     TEXT     27267     4.691741            168587
# 2            2  File103     TEXT     28044     3.370514            174370
# 3            3  File104     TEXT      1886     3.084236             11732
# 4            4  File105     TEXT      1379     4.585926              8735
# ..         ...      ...      ...       ...          ...               ...
# 95          95  File196     TEXT    119678     3.765676            750487
# 96          96  File197     TEXT    167487     3.592673           1051622
# 97          97  File198     TEXT    437315     3.629447           2744823
# 98          98  File199     TEXT    425167     3.743844           2665382
# 99          99  File200     TEXT      4504     4.710598             27871
#
#     FileEntropyAppended  FileSizeSplitted  FileEntropySplitted  \
# ...

# %%
# list of strings
fileOrginalEntropy = list(data['FileEntropy'])
fileName = list(data['FileName'])
fileSizeOrginal = list(data['FileSize'])
Encrypted = [0] * 100

# %%
  
# dictionary of lists 
dict = {'FileName': fileName, 'FileSize': fileSizeOrginal, 'fileEntropy': fileOrginalEntropy,'Encrypted':Encrypted} 
    
dataOrginal = pd.DataFrame(dict)
dataOrginal
# Out:
#    FileName  FileSize  fileEntropy  Encrypted
# 0   File101      1679     4.608124          0
# 1   File102     27267     4.691741          0
# 2   File103     28044     3.370514          0
# 3   File104      1886     3.084236          0
# 4   File105      1379     4.585926          0
# ..      ...       ...          ...        ...
# 95  File196    119678     3.765676          0
# 96  File197    167487     3.592673          0
# 97  File198    437315     3.629447          0
# 98  File199    425167     3.743844          0
# 99  File200      4504     4.710598          0
#
# [100 rows x 4 columns]

# %%
# list of strings
fileEncryptedEntropy = list(data['FileEntropyEncrypted'])
fileNameEncrypted = list(data['FileName']+"Encrypted")
fileSizeEncrypted = list(data['FileSizeEncrypted'])
EncryptedTrue = [1] * 100

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameEncrypted, 'FileSize': fileSizeEncrypted, 'fileEntropy': fileEncryptedEntropy,'Encrypted':EncryptedTrue} 
    
dataEncrypted = pd.DataFrame(dict)
dataEncrypted
# Out:
#             FileName  FileSize  fileEntropy  Encrypted
# 0   File101Encrypted      1696     7.898895          1
# 1   File102Encrypted     27296     7.992885          1
# 2   File103Encrypted     28064     7.991273          1
# 3   File104Encrypted      1904     7.912259          1
# 4   File105Encrypted      1408     7.882455          1
# ..               ...       ...          ...        ...
# 95  File196Encrypted    119696     7.998395          1
# 96  File197Encrypted    167504     7.998898          1
# 97  File198Encrypted    437344     7.999595          1
# 98  File199Encrypted    425184     7.999488          1
# 99  File200Encrypted      4528     7.957862          1
#
# [100 rows x 4 columns]

# %%
# list of strings
fileAppendedEntropy = list(data['FileEntropyAppended'])
fileNameAppended = list(data['FileName']+"Appended")
fileSizeAppended = list(data['FileSizeAppended'])

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameAppended, 'FileSize': fileSizeAppended, 'fileEntropy': fileAppendedEntropy,'Encrypted':Encrypted} 
    
dataAppended = pd.DataFrame(dict)
dataAppended
# Out:
#            FileName  FileSize  fileEntropy  Encrypted
# 0   File101Appended     10553     4.404127          0
# 1   File102Appended    168587     4.434105          0
# 2   File103Appended    174370     4.666963          0
# 3   File104Appended     11732     4.561748          0
# 4   File105Appended      8735     4.500502          0
# ..              ...       ...          ...        ...
# 95  File196Appended    750487     4.820959          0
# 96  File197Appended   1051622     4.728545          0
# 97  File198Appended   2744823     4.849289          0
# 98  File199Appended   2665382     4.798896          0
# 99  File200Appended     27871     4.497601          0
#
# [100 rows x 4 columns]

# %%
# list of strings
fileSplittedEntropy = list(data['FileEntropySplitted'])
fileNameSplitted = list(data['FileName']+"Splitted")
fileSizeSplitted = list(data['FileSizeSplitted'])

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameSplitted, 'FileSize': fileSizeSplitted, 'fileEntropy': fileSplittedEntropy,'Encrypted':Encrypted} 
    
dataSplitted = pd.DataFrame(dict)
dataSplitted
# Out:
#            FileName  FileSize  fileEntropy  Encrypted
# 0   File101Splitted       839     4.566745          0
# 1   File102Splitted     13399     4.605704          0
# 2   File103Splitted     13851     3.487739          0
# 3   File104Splitted       931     3.110641          0
# 4   File105Splitted       689     4.330983          0
# ..              ...       ...          ...        ...
# 95  File196Splitted     59839     3.756558          0
# 96  File197Splitted     83743     3.614790          0
# 97  File198Splitted    218657     3.584758          0
# 98  File199Splitted    212583     3.786854          0
# 99  File200Splitted      2241     4.839218          0
#
# [100 rows x 4 columns]

# %%
dataSet = pd.concat([dataOrginal, dataSplitted, dataAppended, dataEncrypted])

# %%
dataSet
# Out:
#             FileName  FileSize  fileEntropy  Encrypted
# 0            File101      1679     4.608124          0
# 1            File102     27267     4.691741          0
# 2            File103     28044     3.370514          0
# 3            File104      1886     3.084236          0
# 4            File105      1379     4.585926          0
# ..               ...       ...          ...        ...
# 95  File196Encrypted    119696     7.998395          1
# 96  File197Encrypted    167504     7.998898          1
# 97  File198Encrypted    437344     7.999595          1
# 98  File199Encrypted    425184     7.999488          1
# 99  File200Encrypted      4528     7.957862          1
#
# [400 rows x 4 columns]

# %%
feature_names = ['FileSize','fileEntropy']
X = dataSet[feature_names]
y = dataSet['Encrypted']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 1.00
# Accuracy of Logistic regression classifier on test set: 1.00

# %%
def run_exps(X_train: pd.DataFrame , y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame) -> pd.DataFrame:
    dfs = []
    models = [
          ('LogReg', LogisticRegression()), 
          ('RF', RandomForestClassifier()),
          ('KNN', KNeighborsClassifier()),
          ('SVM', SVC()), 
          ('GNB', GaussianNB())]
    results = []
    names = []
    scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
    target_names = ['malignant', 'benign']
    for name, model in models:
        kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
        cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
        clf = model.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        print(name)
        print(classification_report(y_test, y_pred, target_names=target_names))
        results.append(cv_results)
       # names.append(name)
        this_df = pd.DataFrame(cv_results)
        this_df['model'] = name
        dfs.append(this_df)
    final = pd.concat(dfs, ignore_index=True)
    return final

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=8675309)

# %%
run_exps(X_train,y_train,X_test,y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
features = dataSet[feature_names]

# %%
features.describe()
# Out:
#            FileSize  fileEntropy
# count  4.000000e+02   400.000000
# mean   1.446079e+06     5.212145
# std    9.332581e+06     1.679260
# min    1.450000e+02     2.271608
# 25%    9.262750e+03     4.369925
# 50%    6.681700e+04     4.666646
# 75%    4.313682e+05     5.879907
# max    1.695754e+08     7.999993

# %%
# One-hot encode the data using pandas get_dummies
features = pd.get_dummies(features)

# %%
from sklearn.linear_model import LogisticRegression

clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 1.00
# Accuracy of Logistic regression classifier on test set: 1.00

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
