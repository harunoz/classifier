# %%
import os
from collections import Counter
import math
import pandas as pd 

import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('PDFFiles.csv')

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 FileName FileType  FileSize  \
# 0            0             0               0    File1      PDF   1741033
# 1            1             1               1    File2      PDF    422934
# 2            2             2               2    File3      PDF    213174
# 3            3             3               3    File4      PDF   1163575
# 4            4             4               4    File5      PDF    275349
# ..         ...           ...             ...      ...      ...       ...
# 95          95            95              95   File96      PDF     51770
# 96          96            96              96   File97      PDF     29269
# 97          97            97              97   File98      PDF     69431
# 98          98            98              98   File99      PDF    193435
# 99          99            99              99  File100      PDF    277775
#
#     FileEntropy  FileSizeSplitted  FileEntropySplitted  FileSizeAppended  \
# 0      7.970734           1748324             7.968300            602246
# 1      7.894882            392330             7.961129           1851103
# 2      7.939996            205704             7.964573            433853
# 3      7.991709           1143846             7.993807            310372
# 4      7.929471            262585             7.963594            492962
# ..          ...               ...                  ...               ...
# 95     6.445357             55834             6.387584            106429
# 96     7.309334             26938             7.505928             83868
# 97     7.564963             70321             7.554843            255088
# 98     5.104919            188689             5.048452            290028
# 99     7.312377            191257             7.968266           1689673
#
#     FileEntropyAppended  FileEntropyEncrypted  FileSizeEncrypted
# 0              6.939559              7.999890            1741056
# 1              7.971530              7.999572             422960
# 2              7.953827              7.999057             213200
# 3              7.972434              7.999842            1163600
# 4              7.976989              7.999229             275376
# ..                  ...                   ...                ...
# 95             7.484507              7.997074              51792
# 96             7.897299              7.993433              29296
# 97             7.923190              7.997149              69456
# 98             6.518745              7.998975             193456
# 99             7.640141              7.999359             277792
#
# [100 rows x 13 columns]

# %%
# list of strings
fileOrginalEntropy = list(data['FileEntropy'])
fileName = list(data['FileName'])
fileSizeOrginal = list(data['FileSize'])
Encrypted = [0] * 100

# %%
  
# dictionary of lists 
dict = {'FileName': fileName, 'FileSize': fileSizeOrginal, 'fileEntropy': fileOrginalEntropy,'Encrypted':Encrypted} 
    
dataOrginal = pd.DataFrame(dict)
dataOrginal
# Out:
#    FileName  FileSize  fileEntropy  Encrypted
# 0     File1   1741033     7.970734          0
# 1     File2    422934     7.894882          0
# 2     File3    213174     7.939996          0
# 3     File4   1163575     7.991709          0
# 4     File5    275349     7.929471          0
# ..      ...       ...          ...        ...
# 95   File96     51770     6.445357          0
# 96   File97     29269     7.309334          0
# 97   File98     69431     7.564963          0
# 98   File99    193435     5.104919          0
# 99  File100    277775     7.312377          0
#
# [100 rows x 4 columns]

# %%
# list of strings
fileEncryptedEntropy = list(data['FileEntropyEncrypted'])
fileNameEncrypted = list(data['FileName']+"Encrypted")
fileSizeEncrypted = list(data['FileSizeEncrypted'])
EncryptedTrue = [1] * 100

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameEncrypted, 'FileSize': fileSizeEncrypted, 'fileEntropy': fileEncryptedEntropy,'Encrypted':EncryptedTrue} 
    
dataEncrypted = pd.DataFrame(dict)
dataEncrypted
# Out:
#             FileName  FileSize  fileEntropy  Encrypted
# 0     File1Encrypted   1741056     7.999890          1
# 1     File2Encrypted    422960     7.999572          1
# 2     File3Encrypted    213200     7.999057          1
# 3     File4Encrypted   1163600     7.999842          1
# 4     File5Encrypted    275376     7.999229          1
# ..               ...       ...          ...        ...
# 95   File96Encrypted     51792     7.997074          1
# 96   File97Encrypted     29296     7.993433          1
# 97   File98Encrypted     69456     7.997149          1
# 98   File99Encrypted    193456     7.998975          1
# 99  File100Encrypted    277792     7.999359          1
#
# [100 rows x 4 columns]

# %%
# list of strings
fileAppendedEntropy = list(data['FileEntropyAppended'])
fileNameAppended = list(data['FileName']+"Appended")
fileSizeAppended = list(data['FileSizeAppended'])

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameAppended, 'FileSize': fileSizeAppended, 'fileEntropy': fileAppendedEntropy,'Encrypted':Encrypted} 
    
dataAppended = pd.DataFrame(dict)
dataAppended
# Out:
#            FileName  FileSize  fileEntropy  Encrypted
# 0     File1Appended    602246     6.939559          0
# 1     File2Appended   1851103     7.971530          0
# 2     File3Appended    433853     7.953827          0
# 3     File4Appended    310372     7.972434          0
# 4     File5Appended    492962     7.976989          0
# ..              ...       ...          ...        ...
# 95   File96Appended    106429     7.484507          0
# 96   File97Appended     83868     7.897299          0
# 97   File98Appended    255088     7.923190          0
# 98   File99Appended    290028     6.518745          0
# 99  File100Appended   1689673     7.640141          0
#
# [100 rows x 4 columns]

# %%
# list of strings
fileSplittedEntropy = list(data['FileEntropySplitted'])
fileNameSplitted = list(data['FileName']+"Splitted")
fileSizeSplitted = list(data['FileSizeSplitted'])

# %%
  
# dictionary of lists 
dict = {'FileName': fileNameSplitted, 'FileSize': fileSizeSplitted, 'fileEntropy': fileSplittedEntropy,'Encrypted':Encrypted} 
    
dataSplitted = pd.DataFrame(dict)
dataSplitted
# Out:
#            FileName  FileSize  fileEntropy  Encrypted
# 0     File1Splitted   1748324     7.968300          0
# 1     File2Splitted    392330     7.961129          0
# 2     File3Splitted    205704     7.964573          0
# 3     File4Splitted   1143846     7.993807          0
# 4     File5Splitted    262585     7.963594          0
# ..              ...       ...          ...        ...
# 95   File96Splitted     55834     6.387584          0
# 96   File97Splitted     26938     7.505928          0
# 97   File98Splitted     70321     7.554843          0
# 98   File99Splitted    188689     5.048452          0
# 99  File100Splitted    191257     7.968266          0
#
# [100 rows x 4 columns]

# %%
dataAppended
# Out:
#            FileName  FileSize  fileEntropy  Encrypted
# 0     File1Appended    602246     6.939559          0
# 1     File2Appended   1851103     7.971530          0
# 2     File3Appended    433853     7.953827          0
# 3     File4Appended    310372     7.972434          0
# 4     File5Appended    492962     7.976989          0
# ..              ...       ...          ...        ...
# 95   File96Appended    106429     7.484507          0
# 96   File97Appended     83868     7.897299          0
# 97   File98Appended    255088     7.923190          0
# 98   File99Appended    290028     6.518745          0
# 99  File100Appended   1689673     7.640141          0
#
# [100 rows x 4 columns]

# %%
dataSet = pd.concat([dataOrginal, dataSplitted,dataAppended ,dataEncrypted])

# %%
dataSet
# Out:
#             FileName  FileSize  fileEntropy  Encrypted
# 0              File1   1741033     7.970734          0
# 1              File2    422934     7.894882          0
# 2              File3    213174     7.939996          0
# 3              File4   1163575     7.991709          0
# 4              File5    275349     7.929471          0
# ..               ...       ...          ...        ...
# 95   File96Encrypted     51792     7.997074          1
# 96   File97Encrypted     29296     7.993433          1
# 97   File98Encrypted     69456     7.997149          1
# 98   File99Encrypted    193456     7.998975          1
# 99  File100Encrypted    277792     7.999359          1
#
# [400 rows x 4 columns]

# %%
feature_names = ['FileSize','fileEntropy']
X = dataSet[feature_names]
y = dataSet['Encrypted']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=8675309)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
#from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# %%
def run_exps(X_train: pd.DataFrame , y_train: pd.DataFrame, X_test: pd.DataFrame, y_test: pd.DataFrame) -> pd.DataFrame:
    dfs = []
    models = [
          ('LogReg', LogisticRegression()), 
          ('RF', RandomForestClassifier()),
          ('KNN', KNeighborsClassifier()),
          ('SVM', SVC()), 
          ('GNB', GaussianNB())]
    results = []
    names = []
    scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
    target_names = ['malignant', 'benign']
    for name, model in models:
        kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
        cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
        clf = model.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        print(name)
        print(classification_report(y_test, y_pred, target_names=target_names))
        results.append(cv_results)
       # names.append(name)
        this_df = pd.DataFrame(cv_results)
        this_df['model'] = name
        dfs.append(this_df)
    final = pd.concat(dfs, ignore_index=True)
    return final

# %%
run_exps(X_train,y_train,X_test,y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.76      1.00      0.86        76
#       benign       0.00      0.00      0.00        24
#
#     accuracy                           0.76       100
#    macro avg       0.38      0.50      0.43       100
# weighted avg       0.58      0.76      0.66       100
#
# RF
#               precision    recall  f1-score   support
#
#    malignant       1.00      1.00      1.00        76
#       benign       1.00      1.00      1.00        24
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.75      0.92      0.83        76
#       benign       0.14      0.04      0.06        24
#
#     accuracy                           0.71       100
#    macro avg       0.45      0.48      0.45       100
# weighted avg       0.61      0.71      0.65       100
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.76      1.00      0.86        76
#       benign       0.00      0.00      0.00        24
#
#     accuracy                           0.76       100
#    macro avg       0.38      0.50      0.43       100
# weighted avg       0.58      0.76      0.66       100
#
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.76      1.00      0.86        76
#       benign       0.00      0.00      0.00        24
#
#     accuracy                           0.76       100
#    macro avg       0.38      0.50      0.43       100
# weighted avg       0.58      0.76      0.66       100
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.024790    0.026020       0.733333                 0.537778
# 1   0.012114    0.014413       0.733333                 0.537778
# 2   0.011223    0.009647       0.833333                 0.694444
# 3   0.007354    0.009252       0.733333                 0.537778
# 4   0.007075    0.008658       0.700000                 0.490000
# 5   0.168996    0.033699       1.000000                 1.000000
# 6   0.158234    0.031130       0.950000                 0.953191
# 7   0.162306    0.035003       1.000000                 1.000000
# 8   0.203027    0.054605       0.983333                 0.984314
# 9   0.176388    0.030644       1.000000                 1.000000
# 10  0.003426    0.013735       0.633333                 0.581333
# 11  0.002831    0.012636       0.683333                 0.527485
# 12  0.003643    0.016390       0.800000                 0.689655
# 13  0.002986    0.017965       0.666667                 0.523810
# 14  0.002937    0.016202       0.666667                 0.482759
# 15  0.005419    0.017390       0.733333                 0.537778
# 16  0.006876    0.018822       0.733333                 0.537778
# 17  0.006042    0.015833       0.833333                 0.694444
# 18  0.005654    0.027030       0.733333                 0.537778
# 19  0.010814    0.021776       0.700000                 0.490000
# 20  0.007436    0.027415       0.733333                 0.537778
# 21  0.003854    0.013249       0.733333                 0.537778
# 22  0.004130    0.014243       0.833333                 0.694444
# 23  0.006287    0.022684       0.733333                 0.537778
# 24  0.007275    0.013590       0.700000                 0.490000
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.733333          0.620513      0.473011  LogReg
# 1               0.733333          0.620513      0.573864  LogReg
# 2               0.833333          0.757576      0.768000  LogReg
# 3               0.733333          0.620513      0.490057  LogReg
# 4               0.700000          0.576471      0.580688  LogReg
# 5               1.000000          1.000000      1.000000      RF
# 6               0.950000          0.948238      1.000000      RF
# 7               1.000000          1.000000      1.000000      RF
# 8               0.983333          0.983490      1.000000      RF
# 9               1.000000          1.000000      1.000000      RF
# 10              0.633333          0.602728      0.394886     KNN
# 11              0.683333          0.595380      0.271307     KNN
# 12              0.800000          0.740741      0.489000     KNN
# 13              0.666667          0.586667      0.362926     KNN
# 14              0.666667          0.560000      0.456349     KNN
# 15              0.733333          0.620513      0.541193     SVM
# 16              0.733333          0.620513      0.373580     SVM
# 17              0.833333          0.757576      0.512000     SVM
# 18              0.733333          0.620513      0.427557     SVM
# 19              0.700000          0.576471      0.427249     SVM
# 20              0.733333          0.620513      0.490057     GNB
# 21              0.733333          0.620513      0.471591     GNB
# 22              0.833333          0.757576      0.564000     GNB
# 23              0.733333          0.620513      0.502841     GNB
# 24              0.700000          0.576471      0.584656     GNB

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.75
# Accuracy of Logistic regression classifier on test set: 0.76

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
clf=RandomForestRegressor(n_estimators=100)
clf.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.99
# Accuracy of Logistic regression classifier on test set: 0.97

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

# %%
# Limit depth of tree to 3 levels
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 3)
rf_small.fit(X_train, y_train)
# Extract the small tree
tree_small = rf_small.estimators_[5]
# Save the tree as a png image
export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = feature_names, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png');
# Out:
# DecisionTreeRegressor(max_depth=3, max_features='auto', random_state=1224132383)

# %%
# Get numerical feature importances
importances = list(clf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(X, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: fileEntropy          Importance: 0.95
# Variable: FileSize             Importance: 0.05
